# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
from matplotlib import font_manager
file = 'NSDUH_2019.DTA'
df = pd.read_stata(file)
df.head()
# Out:
#    QUESTID2    filedate  cigever              cigofrsm              cigwilyr  \
# 0  43295143  10/09/2020  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1  65095143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2  49405143  10/09/2020  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3  51015143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4  31825143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#                         cigtry                        cigyfu  \
# 0                           13        9999 - LEGITIMATE SKIP
# 1  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
# 2                           22        9999 - LEGITIMATE SKIP
# 3  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
# 4  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
#
#                        cigmfu                      cigrec  \
# 0        99 - LEGITIMATE SKIP   4 - More than 3 years ago
# ...

# %%
#SET STYLE FOR REST OF NOTEBOOK
matplotlib.style.use('seaborn') #set stylesheet
matplotlib.rcParams['font.size'] = 20
matplotlib.rcParams['figure.figsize'] = (15, 12) #standardise figure size
matplotlib.rcParams['font.family'] = 'Verdana'
#matplotlib.rcParams['font.weight'] =  'bold' #<-consider adding this line (uncommented) if using a thin font

# %%
#GET Fonts and write to file fonts.txt in same folder (NOTE: not every font will work)
fonts = font_manager.findSystemFonts(fontpaths = None, fontext = 'ttf')
file = open('fonts.txt', 'w')
file.write(str(fonts))
# Out:
# 19756

# %%
#print(list(df))
#print(len(df))
#print(len(list(df)))

# %%
col = 'yowrwrth'
col_name = '\"Surveyed Response\" [Teenagers]'
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)[:2]
print(freq)
# Out:
#   "Surveyed Response" [Teenagers]  freq
# 1                         1 - Yes  2014
# 2                          2 - No   619

# %%
ax = freq.plot.bar(x = col_name, y='freq', color = ['navy', 'green'], rot=1, fontsize = 15)
plt.title('\"When problems worsen, feel totally worthless daily\" [Teenagers]', fontsize = 20)
plt.xlabel(col_name, fontsize=20)
plt.savefig('Congy_Bar4.png', dpi = 300)
