# %%
import pandas as pd
import matplotlib.pyplot as plt
file = 'NSDUH_2019.DTA'
df = pd.read_stata(file)
df.head()
# Out:
#    QUESTID2    filedate  cigever              cigofrsm              cigwilyr  \
# 0  43295143  10/09/2020  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 1  65095143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 2  49405143  10/09/2020  1 - Yes  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 3  51015143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
# 4  31825143  10/09/2020   2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#                         cigtry                        cigyfu  \
# 0                           13        9999 - LEGITIMATE SKIP
# 1  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
# 2                           22        9999 - LEGITIMATE SKIP
# 3  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
# 4  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
#
#                        cigmfu                      cigrec  \
# 0        99 - LEGITIMATE SKIP   4 - More than 3 years ago
# ...

# %%
df.loc[[10]]
# Out:
#     QUESTID2    filedate cigever              cigofrsm              cigwilyr  \
# 10  89306143  10/09/2020  2 - No  99 - LEGITIMATE SKIP  99 - LEGITIMATE SKIP
#
#                          cigtry                        cigyfu  \
# 10  991 - NEVER USED CIGARETTES  9991 - NEVER USED CIGARETTES
#
#                         cigmfu                      cigrec  \
# 10  91 - NEVER USED CIGARETTES  91 - NEVER USED CIGARETTES
#
#                       CIG30USE  ...                            POVERTY3  \
# 10  91 - NEVER USED CIGARETTES  ...  2 - Income Up to 2X Fed Pov Thresh
#
#    toolong troubund                                             PDEN10  \
# 10  2 - No   2 - No  2 - Segm. in a CBSA with fewer than 1 million ...
#
#             COUTYP4                                    MAIIN102  \
# 10  2 - Small Metro  2 - Segment not in an American Indian area
#
#                                            AIIND102     ANALWT_C  vestr verep
# ...

# %%
print(list(df))
print(len(df))
print(len(list(df)))
# Out:
# ['QUESTID2', 'filedate', 'cigever', 'cigofrsm', 'cigwilyr', 'cigtry', 'cigyfu', 'cigmfu', 'cigrec', 'CIG30USE', 'CG30EST', 'CIG30AV', 'CIG30BR2', 'CIG30TPE', 'CIG30MEN', 'CIG30MLN', 'CIG30RO2', 'cigdlymo', 'cigage', 'cigdlyfu', 'cigdlmfu', 'CIG100LF', 'smklssevr', 'smklsstry', 'smklssyfu', 'smklssmfu', 'smklssrec', 'SMKLSS30N', 'SMKLSS30E', 'cigarevr', 'cigartry', 'cigaryfu', 'cigarmfu', 'cigarrec', 'CGR30USE', 'CI30EST', 'CGR30BR2', 'pipever', 'PIPE30DY', 'alcever', 'alctry', 'alcyfu', 'alcmfu', 'alcrec', 'alcyrtot', 'altotfg', 'alfqflg', 'albstway', 'aldaypyr', 'aldaypmo', 'aldaypwk', 'alcdays', 'AL30EST', 'aldysfg', 'ALCUS30D', 'ALCBNG30D', 'mjever', 'mjage', 'mjyfu', 'mjmfu', 'mjrec', 'mjyrtot', 'mrtotfg', 'mjfqflg', 'mrbstway', 'mrdaypyr', 'mrdaypmo', 'mrdaypwk', 'MJDAY30A', 'MR30EST', 'cocever', 'cocage', 'cocyfu', 'cocmfu', 'cocrec', 'cocyrtot', 'cctotfg', 'ccfqflg', 'ccbstway', 'ccdaypyr', 'ccdaypmo', 'ccdaypwk', 'COCUS30A', 'CC30EST', 'crkever', 'crkage', 'crkyfu', 'crkmfu',
# ...

# %%
col = 'yowrwrth'
col_name = '\"When problems worsen, feel totally worthless daily\" [Teenagers]'
freq = df[col].value_counts().rename_axis(col_name).reset_index(name='freq')
freq = freq.sort_values(by = col_name)[:2]
print(freq)
# Out:
#   "When problems worsen, feel totally worthless daily" [Teenagers]  freq
# 1                                            1 - Yes                2014
# 2                                             2 - No                 619

# %%
ax = freq.plot.bar(x=col_name, y='freq', color="navy", rot=1)
